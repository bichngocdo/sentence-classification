# %%
import pandas as pd

from sentclf.experiment import Experiment

# %% [markdown]
# # Data

# %% [markdown]
# ## Load Data

# %%
data_path = '../SPSC.csv'

data = pd.read_csv(data_path)
data['sentence'] = data['sentence'].astype('str')
data['label'] = data['label'].astype('category')
data.head()
# Out:
#                                                 file  \
# 0  data/101.tar_1804.04614.gz_CMN_Final_Draft_1.json
# 1  data/101.tar_1804.04614.gz_CMN_Final_Draft_1.json
# 2  data/101.tar_1804.04614.gz_CMN_Final_Draft_1.json
# 3  data/101.tar_1804.04614.gz_CMN_Final_Draft_1.json
# 4  data/101.tar_1804.04614.gz_CMN_Final_Draft_1.json
#
#                                             sentence      label  position  \
# 0                                  (cid:18) (cid:19)   equation         0
# 1  unknown. If we treat these unknown parameters,...  paragraph         1
# 2                                       − y Ax || ||   equation         2
# 3                 to ﬁnd the original sparse signal.  paragraph         3
# 4                              The EM algorithm [13]  paragraph         4
#
#    xmin  xmax  ymin  ymax
# 0   718   800    52    99
# 1    80   490    68    98
# 2   732   857    81   111
# 3    80   315    97   112
# 4   324   490    97   112

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Config

# %%
config = {
    'data': {
        'random_states': [
              98237834,
              124104,
        ],
    },
    'dataset': {
        'name': 'Uizard',
    },
    'data_loaders': {
        'train_batch_size': 32,
        'dev_batch_size': 64,
        'test_batch_size': 64,
    },
    'model': {
        'pretrained_model': 'allenai/scibert_scivocab_uncased',
        'pooling_mode': 'mean',
        'dropout_prob': 0.1,
        'use_extended_features': True,
    },
    'optimizer': {
        'type': 'Adam',
        'learning_rate': 5e-6,
        'learning_rate_top': 5e-4,
    },
    'trainer': {
        'num_epochs': 1,
        'interval': 200,
    },
    'paths': {
        'output_dir': 'model'
    },
    'logger': {
        'level': 'INFO',
    }
}

# %% [markdown]
# ## Initialization

# %%
experiment = Experiment(
    config,
    data=data,
)
# Out:
# 2021-10-20 17:13:10,212 - sentclf.experiment - Python random seed: 833907329
# 2021-10-20 17:13:10,213 - sentclf.experiment - NumPy random seed: 2231472547
# 2021-10-20 17:13:10,215 - sentclf.experiment - Torch random seed: 2328329906
# 2021-10-20 17:13:10,281 - sentclf.experiment - Use device: cuda
# 2021-10-20 17:13:10,284 - sentclf.experiment - Create experiment directory: model/Uizard_211020_17-13-10
# Some weights of the model checkpoint at allenai/scibert_scivocab_uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
experiment.train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 366949 entries, 27695 to 98630
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   file      366949 non-null  object
#  1   sentence  366949 non-null  object
#  2   label     366949 non-null  category
#  3   position  366949 non-null  int64
#  4   xmin      366949 non-null  int64
#  5   xmax      366949 non-null  int64
#  6   ymin      366949 non-null  int64
#  7   ymax      366949 non-null  int64
# dtypes: category(1), int64(5), object(2)
# memory usage: 22.7+ MB

# %%
experiment.dev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45869 entries, 48038 to 115095
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   file      45869 non-null  object
#  1   sentence  45869 non-null  object
#  2   label     45869 non-null  category
#  3   position  45869 non-null  int64
#  4   xmin      45869 non-null  int64
#  5   xmax      45869 non-null  int64
#  6   ymin      45869 non-null  int64
#  7   ymax      45869 non-null  int64
# dtypes: category(1), int64(5), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Training

# %%
experiment.train()
# Out:
# 2021-10-20 17:13:18,801 - sentclf.trainer - Total no. iterations: 11468
# Epoch 0, iteration 0:
# /home/ndo/.conda/envs/nlp_gpu/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ndo/.conda/envs/nlp_gpu/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   eval_time = 10.07438139905571
#   eval_time_scoring = 0.11098297899297904
#   eval_loss = 40.84889081058312
#   eval_macro_p = 0.0019956498187983502
#   eval_macro_r = 0.07692307692307693
#   eval_macro_f1 = 0.003890370026497016
#   eval_acc = 0.025943447644378555
#   eval_f1_abstract = 0.0
#   eval_f1_author = 0.0
#   eval_f1_caption = 0.0
#   eval_f1_date = 0.0
#   eval_f1_equation = 0.0
#   eval_f1_figure = 0.0
#   eval_f1_footer = 0.0
#   eval_f1_list = 0.05057481034446121
#   eval_f1_paragraph = 0.0
#   eval_f1_reference = 0.0
#   eval_f1_section = 0.0
#   eval_f1_table = 0.0
#   eval_f1_title = 0.0
# Epoch 1, iteration 200:
#   train_time = 35.01731442895834
#   train_loss = 9.229577479660511
# /home/ndo/.conda/envs/nlp_gpu/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ndo/.conda/envs/nlp_gpu/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   eval_time = 9.689445942887687
#   eval_time_scoring = 0.09700121900823433
#   eval_loss = 2.2544771509882215
#   eval_macro_p = 0.32482768820504665
#   eval_macro_r = 0.560706142993481
#   eval_macro_f1 = 0.35980594201113647
#   eval_acc = 0.5863655191959711
#   eval_f1_abstract = 0.1525643399370487
#   eval_f1_author = 0.5344036697247706
#   eval_f1_caption = 0.24399260628465802
#   eval_f1_date = 0.0
#   eval_f1_equation = 0.60198342214328
#   eval_f1_figure = 0.539647577092511
#   eval_f1_footer = 0.13624454148471615
#   eval_f1_list = 0.03410641200545703
#   eval_f1_paragraph = 0.6697822716254287
#   eval_f1_reference = 0.7379386775027706
#   eval_f1_section = 0.6344476744186046
#   eval_f1_table = 0.32664756446991405
#   eval_f1_title = 0.0657184894556155
# Save best model
# Epoch 1, iteration 400:
#   train_time = 34.05161179881543
#   train_loss = 1.721812286451459
#   eval_time = 9.68443620101607
#   eval_time_scoring = 0.09891410700220149
#   eval_loss = 0.9925076817823737
#   eval_macro_p = 0.4368826018102169
#   eval_macro_r = 0.7119888485833427
#   eval_macro_f1 = 0.4932645819205324
#   eval_acc = 0.5740696330855262
#   eval_f1_abstract = 0.13075528700906344
#   eval_f1_author = 0.7206896551724138
#   eval_f1_caption = 0.4410726887791108
#   eval_f1_date = 0.5079365079365079
#   eval_f1_equation = 0.7832465185500159
#   eval_f1_figure = 0.6468305304010349
#   eval_f1_footer = 0.16955995155429957
#   eval_f1_list = 0.14372061786433848
#   eval_f1_paragraph = 0.5759095062856578
#   eval_f1_reference = 0.8682697657167584
#   eval_f1_section = 0.5995609909062402
#   eval_f1_table = 0.3753462603878116
#   eval_f1_title = 0.4495412844036697
# Save best model
# Epoch 1, iteration 600:
#   train_time = 34.731785853917245
#   train_loss = 1.3071133806742727
#   eval_time = 9.73884292904404
#   eval_time_scoring = 0.09705023100832477
#   eval_loss = 0.8334834139452436
#   eval_macro_p = 0.5162375128304926
#   eval_macro_r = 0.7559832630145754
#   eval_macro_f1 = 0.5407619790734771
#   eval_acc = 0.4969587302971506
#   eval_f1_abstract = 0.18921440567270012
#   eval_f1_author = 0.7423312883435583
#   eval_f1_caption = 0.44614290792747957
#   eval_f1_date = 0.3157894736842105
#   eval_f1_equation = 0.7849349559378934
#   eval_f1_figure = 0.9881422924901185
#   eval_f1_footer = 0.3342245989304813
#   eval_f1_list = 0.11335324542871712
#   eval_f1_paragraph = 0.4288158984267182
#   eval_f1_reference = 0.8696630618240919
#   eval_f1_section = 0.8710512687726566
#   eval_f1_table = 0.4902162718846551
#   eval_f1_title = 0.45602605863192186
# Save best model
# Epoch 1, iteration 800:
#   train_time = 35.05536276195198
#   train_loss = 0.8205308985337615
#   eval_time = 9.719473107077647
#   eval_time_scoring = 0.09628240400343202
#   eval_loss = 0.7426042425803745
#   eval_macro_p = 0.5382995007866719
#   eval_macro_r = 0.7719145881483512
#   eval_macro_f1 = 0.5917144142778523
#   eval_acc = 0.6457956353964551
#   eval_f1_abstract = 0.23976889744824267
#   eval_f1_author = 0.6739427012278308
#   eval_f1_caption = 0.517899249732047
#   eval_f1_date = 0.6666666666666667
#   eval_f1_equation = 0.8041172800998129
#   eval_f1_figure = 0.9784735812133072
#   eval_f1_footer = 0.35323383084577115
#   eval_f1_list = 0.15924555330070428
#   eval_f1_paragraph = 0.6685600812782858
#   eval_f1_reference = 0.8745948641236599
#   eval_f1_section = 0.8547249647390691
#   eval_f1_table = 0.5257510729613735
#   eval_f1_title = 0.3753086419753086
# Save best model
# Epoch 1, iteration 1000:
#   train_time = 34.17112235190871
#   train_loss = 0.9124357345886529
#   eval_time = 9.713664924827754
#   eval_time_scoring = 0.09980692301178351
#   eval_loss = 1.1315546011596762
#   eval_macro_p = 0.5087795918818842
#   eval_macro_r = 0.7277069263107946
#   eval_macro_f1 = 0.49926878821601284
#   eval_acc = 0.46892236586801544
#   eval_f1_abstract = 0.09612944162436549
#   eval_f1_author = 0.17908407382091593
#   eval_f1_caption = 0.2936335256834736
#   eval_f1_date = 0.44859813084112143
#   eval_f1_equation = 0.7000272702481591
#   eval_f1_figure = 0.996
#   eval_f1_footer = 0.37744533947065595
#   eval_f1_list = 0.2247191011235955
#   eval_f1_paragraph = 0.4831785020731643
#   eval_f1_reference = 0.7954792436426864
#   eval_f1_section = 0.8187082405345211
#   eval_f1_table = 0.5489199491740787
#   eval_f1_title = 0.5285714285714286
# Epoch 1, iteration 1200:
#   train_time = 34.69242336193565
#   train_loss = 0.9154704514611512
#   eval_time = 9.7224132768024
#   eval_time_scoring = 0.09843178300070576
#   eval_loss = 0.6898004376331329
#   eval_macro_p = 0.5102376853084495
#   eval_macro_r = 0.8069857832395512
#   eval_macro_f1 = 0.5548869441572359
#   eval_acc = 0.5223353463123243
#   eval_f1_abstract = 0.17106842737094838
#   eval_f1_author = 0.7614533965244865
#   eval_f1_caption = 0.4921383647798742
#   eval_f1_date = 0.5274725274725275
#   eval_f1_equation = 0.8239429339398325
#   eval_f1_figure = 0.9920634920634921
#   eval_f1_footer = 0.14829106945975745
#   eval_f1_list = 0.15348261505569935
#   eval_f1_paragraph = 0.452054794520548
#   eval_f1_reference = 0.8740051426472389
#   eval_f1_section = 0.8146868250539958
#   eval_f1_table = 0.5080971659919028
#   eval_f1_title = 0.49477351916376305
# Epoch 1, iteration 1400:
#   train_time = 34.436383021849906
#   train_loss = 0.9953165735676884
#   eval_time = 9.696570747997612
#   eval_time_scoring = 0.09544838100555353
#   eval_loss = 0.7751288116244629
#   eval_macro_p = 0.568460543910236
#   eval_macro_r = 0.7838232949936508
#   eval_macro_f1 = 0.6193297744855398
#   eval_acc = 0.6702566003182978
#   eval_f1_abstract = 0.40083507306889354
#   eval_f1_author = 0.6666666666666667
#   eval_f1_caption = 0.31244667741018106
#   eval_f1_date = 0.7540983606557377
#   eval_f1_equation = 0.8179397911120213
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.18724046810117026
#   eval_f1_list = 0.3139763779527559
#   eval_f1_paragraph = 0.6958647382358932
#   eval_f1_reference = 0.8748910743184365
#   eval_f1_section = 0.8719424460431655
#   eval_f1_table = 0.5207700101317122
#   eval_f1_title = 0.6346153846153845
# Save best model
# Epoch 1, iteration 1600:
#   train_time = 35.41675309819402
#   train_loss = 0.8818414419516921
#   eval_time = 9.687411676859483
#   eval_time_scoring = 0.09757420400273986
#   eval_loss = 0.7266968806240754
#   eval_macro_p = 0.5328417645631921
#   eval_macro_r = 0.8073565193808853
#   eval_macro_f1 = 0.5703071381313574
#   eval_acc = 0.525845342170093
#   eval_f1_abstract = 0.19875130072840794
#   eval_f1_author = 0.675603217158177
#   eval_f1_caption = 0.3819883632684038
#   eval_f1_date = 0.8070175438596493
#   eval_f1_equation = 0.7992693322508626
#   eval_f1_figure = 0.9960159362549801
#   eval_f1_footer = 0.13570038910505836
#   eval_f1_list = 0.17605314812018721
#   eval_f1_paragraph = 0.45841840206887174
#   eval_f1_reference = 0.8726780661828023
#   eval_f1_section = 0.8730468750000001
#   eval_f1_table = 0.5589307411907655
#   eval_f1_title = 0.4805194805194805
# Epoch 1, iteration 1800:
#   train_time = 34.27073770100833
#   train_loss = 0.9126201117038727
#   eval_time = 9.68695641407976
#   eval_time_scoring = 0.0971906500053592
#   eval_loss = 0.6682618902560662
#   eval_macro_p = 0.5352834969915539
#   eval_macro_r = 0.818007334708592
#   eval_macro_f1 = 0.5950044858232894
#   eval_acc = 0.6336959602345811
#   eval_f1_abstract = 0.2005449591280654
#   eval_f1_author = 0.6298619824341279
#   eval_f1_caption = 0.5216144232739194
#   eval_f1_date = 0.761904761904762
#   eval_f1_equation = 0.8221665623043206
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.22765673632725658
#   eval_f1_list = 0.20528620074590564
#   eval_f1_paragraph = 0.6420258466811053
#   eval_f1_reference = 0.8718354430379747
#   eval_f1_section = 0.8864970645792565
#   eval_f1_table = 0.41951219512195126
#   eval_f1_title = 0.548148148148148
# Epoch 1, iteration 2000:
#   train_time = 34.648422808910254
#   train_loss = 0.7396943271718919
#   eval_time = 9.679593614855548
#   eval_time_scoring = 0.0958158120047301
#   eval_loss = 0.6931699876806693
#   eval_macro_p = 0.5464821936311424
#   eval_macro_r = 0.8079636135279882
#   eval_macro_f1 = 0.6117173570307741
#   eval_acc = 0.7576794785149011
#   eval_f1_abstract = 0.30335411101216975
#   eval_f1_author = 0.4961240310077519
#   eval_f1_caption = 0.562962962962963
#   eval_f1_date = 0.7164179104477612
#   eval_f1_equation = 0.8333683546963647
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.472
#   eval_f1_list = 0.29866858582223826
#   eval_f1_paragraph = 0.8030038779571989
#   eval_f1_reference = 0.875955028262625
#   eval_f1_section = 0.8774627582892841
#   eval_f1_table = 0.29518072289156627
#   eval_f1_title = 0.41782729805013924
# Epoch 1, iteration 2200:
#   train_time = 33.86263613801566
#   train_loss = 0.8359421296417713
#   eval_time = 9.733135677088285
#   eval_time_scoring = 0.09383340399654116
#   eval_loss = 1.0808726339390733
#   eval_macro_p = 0.6097920450459962
#   eval_macro_r = 0.725359153165721
#   eval_macro_f1 = 0.5695375650896809
#   eval_acc = 0.39992151562057165
#   eval_f1_abstract = 0.3228602383531961
#   eval_f1_author = 0.7294469357249627
#   eval_f1_caption = 0.5160167130919219
#   eval_f1_date = 0.8
#   eval_f1_equation = 0.8357317983157446
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.3695652173913043
#   eval_f1_list = 0.08169014084507042
#   eval_f1_paragraph = 0.22503303756843498
#   eval_f1_reference = 0.8745385144859522
#   eval_f1_section = 0.8562386980108498
#   eval_f1_table = 0.5853658536585366
#   eval_f1_title = 0.20949720670391062
# Epoch 1, iteration 2400:
#   train_time = 34.10396328711067
#   train_loss = 0.8985777446441352
#   eval_time = 9.66291911478038
#   eval_time_scoring = 0.09562876599375159
#   eval_loss = 0.7345846912116492
#   eval_macro_p = 0.5301468976199414
#   eval_macro_r = 0.795205260906428
#   eval_macro_f1 = 0.578697806150153
#   eval_acc = 0.6366609256796529
#   eval_f1_abstract = 0.3976483164083378
#   eval_f1_author = 0.6623207301173403
#   eval_f1_caption = 0.5333861700019813
#   eval_f1_date = 0.6153846153846153
#   eval_f1_equation = 0.7732257657884783
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.08874426859931964
#   eval_f1_list = 0.2818181818181818
#   eval_f1_paragraph = 0.6762874279017397
#   eval_f1_reference = 0.8720344191763982
#   eval_f1_section = 0.8528336380255941
#   eval_f1_table = 0.19266055045871558
#   eval_f1_title = 0.5787234042553192
# Epoch 1, iteration 2600:
#   train_time = 33.856550829921616
#   train_loss = 0.8785269022639841
#   eval_time = 9.692019247770077
#   eval_time_scoring = 0.09644216399465222
#   eval_loss = 0.7762251267130342
#   eval_macro_p = 0.5958706959802064
#   eval_macro_r = 0.7973071601947971
#   eval_macro_f1 = 0.6436062682104041
#   eval_acc = 0.739911487060978
#   eval_f1_abstract = 0.23511777301927198
#   eval_f1_author = 0.6355611601513241
#   eval_f1_caption = 0.5224409448818897
#   eval_f1_date = 0.6399999999999999
#   eval_f1_equation = 0.8423529411764706
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.47285464098073554
#   eval_f1_list = 0.26996007984031933
#   eval_f1_paragraph = 0.7855332585483402
#   eval_f1_reference = 0.8760883280757098
#   eval_f1_section = 0.9040428641013152
#   eval_f1_table = 0.6134969325153373
#   eval_f1_title = 0.5714285714285714
# Save best model
# Epoch 1, iteration 2800:
#   train_time = 33.607234401104506
#   train_loss = 0.8686532847024501
#   eval_time = 9.962017987927538
#   eval_time_scoring = 0.09637095099606086
#   eval_loss = 0.7089107066945816
#   eval_macro_p = 0.5617733119641906
#   eval_macro_r = 0.8095508926135933
#   eval_macro_f1 = 0.6134065732756299
#   eval_acc = 0.7106760557239094
#   eval_f1_abstract = 0.25546448087431695
#   eval_f1_author = 0.7153284671532848
#   eval_f1_caption = 0.5751181102362205
#   eval_f1_date = 0.7164179104477612
#   eval_f1_equation = 0.8171222716677262
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.24814422057264054
#   eval_f1_list = 0.2422092728654675
#   eval_f1_paragraph = 0.7515611346731741
#   eval_f1_reference = 0.8796515245799627
#   eval_f1_section = 0.8937969924812029
#   eval_f1_table = 0.2746294681778553
#   eval_f1_title = 0.6068376068376068
# Epoch 1, iteration 3000:
#   train_time = 33.93021695509378
#   train_loss = 0.9929459980502725
#   eval_time = 9.955999340993003
#   eval_time_scoring = 0.09763584900065325
#   eval_loss = 1.1788857938439266
#   eval_macro_p = 0.6292477990887644
#   eval_macro_r = 0.7489140456399943
#   eval_macro_f1 = 0.6087340204257615
#   eval_acc = 0.505679216900303
#   eval_f1_abstract = 0.13064425770308122
#   eval_f1_author = 0.674698795180723
#   eval_f1_caption = 0.24758888728947742
#   eval_f1_date = 0.7741935483870968
#   eval_f1_equation = 0.8204475554141479
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.49615384615384617
#   eval_f1_list = 0.28340392760877936
#   eval_f1_paragraph = 0.43658952229124287
#   eval_f1_reference = 0.8719208719208719
#   eval_f1_section = 0.8794466403162056
#   eval_f1_table = 0.6210350584307178
#   eval_f1_title = 0.6774193548387097
# Epoch 1, iteration 3200:
#   train_time = 34.967776706966106
#   train_loss = 0.9570391023159027
#   eval_time = 9.956381778931245
#   eval_time_scoring = 0.09693717799382284
#   eval_loss = 0.73284693361927
#   eval_macro_p = 0.5010602592581828
#   eval_macro_r = 0.8133745763497834
#   eval_macro_f1 = 0.5695798448521551
#   eval_acc = 0.6550393511957967
#   eval_f1_abstract = 0.2349846558526962
#   eval_f1_author = 0.766025641025641
#   eval_f1_caption = 0.4873511904761904
#   eval_f1_date = 0.6233766233766235
#   eval_f1_equation = 0.8301125504353366
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.35555555555555557
#   eval_f1_list = 0.21405929517061345
#   eval_f1_paragraph = 0.6723609692693344
#   eval_f1_reference = 0.852976049324164
#   eval_f1_section = 0.7181208053691275
#   eval_f1_table = 0.3830594184576485
#   eval_f1_title = 0.26855123674911663
# Epoch 1, iteration 3400:
#   train_time = 34.24315480895166
#   train_loss = 0.7483582317084074
#   eval_time = 9.967800388039905
#   eval_time_scoring = 0.09659228999225888
#   eval_loss = 0.7176783787691948
#   eval_macro_p = 0.5456382127135445
#   eval_macro_r = 0.8105291141592146
#   eval_macro_f1 = 0.6101847097837273
#   eval_acc = 0.685059626327149
#   eval_f1_abstract = 0.3191881918819188
#   eval_f1_author = 0.5359749739311783
#   eval_f1_caption = 0.5597033374536464
#   eval_f1_date = 0.761904761904762
#   eval_f1_equation = 0.8015351984648015
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.4070175438596491
#   eval_f1_list = 0.20145018915510718
#   eval_f1_paragraph = 0.7195018524304782
#   eval_f1_reference = 0.8763706999185412
#   eval_f1_section = 0.8242838820008551
#   eval_f1_table = 0.250996015936255
#   eval_f1_title = 0.6764705882352942
# Epoch 1, iteration 3600:
#   train_time = 34.06423480005469
#   train_loss = 0.9161146275512874
#   eval_time = 9.961653711143299
#   eval_time_scoring = 0.095895439008018
#   eval_loss = 0.9546046273911942
#   eval_macro_p = 0.6209901652772303
#   eval_macro_r = 0.7773738233881351
#   eval_macro_f1 = 0.6566397680224095
#   eval_acc = 0.7435740914343021
#   eval_f1_abstract = 0.24749316317228806
#   eval_f1_author = 0.7800687285223368
#   eval_f1_caption = 0.4596551724137931
#   eval_f1_date = 0.8421052631578948
#   eval_f1_equation = 0.8251930598736336
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.450261780104712
#   eval_f1_list = 0.33478735005452565
#   eval_f1_paragraph = 0.7859192092643393
#   eval_f1_reference = 0.880475129918337
#   eval_f1_section = 0.6375968992248062
#   eval_f1_table = 0.6516129032258066
#   eval_f1_title = 0.6411483253588516
# Save best model
# Epoch 1, iteration 3800:
#   train_time = 34.55707918891858
#   train_loss = 0.7891678022034466
#   eval_time = 9.969821590930223
#   eval_time_scoring = 0.09822458001144696
#   eval_loss = 0.7253950816289851
#   eval_macro_p = 0.49598221578835067
#   eval_macro_r = 0.8107618938358271
#   eval_macro_f1 = 0.521441618150494
#   eval_acc = 0.4718655300965794
#   eval_f1_abstract = 0.19434752267969296
#   eval_f1_author = 0.3909774436090226
#   eval_f1_caption = 0.40703308874428906
#   eval_f1_date = 0.7719298245614035
#   eval_f1_equation = 0.832538925961233
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.10403272939801285
#   eval_f1_list = 0.1548032061251346
#   eval_f1_paragraph = 0.3478108068531264
#   eval_f1_reference = 0.8741025006189651
#   eval_f1_section = 0.8886649874055416
#   eval_f1_table = 0.45352564102564097
#   eval_f1_title = 0.358974358974359
# Epoch 1, iteration 4000:
#   train_time = 33.739863993032486
#   train_loss = 0.8255267909914256
#   eval_time = 9.945323005085811
#   eval_time_scoring = 0.09621567800058983
#   eval_loss = 0.7861996560352578
#   eval_macro_p = 0.5879567109348975
#   eval_macro_r = 0.7893986399705314
#   eval_macro_f1 = 0.5957927557970862
#   eval_acc = 0.46842093788833417
#   eval_f1_abstract = 0.3037383177570093
#   eval_f1_author = 0.7040673211781205
#   eval_f1_caption = 0.5702849069931717
#   eval_f1_date = 0.7796610169491525
#   eval_f1_equation = 0.7907692307692308
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.13406488549618317
#   eval_f1_list = 0.11186217622779207
#   eval_f1_paragraph = 0.3842764776563483
#   eval_f1_reference = 0.8728818858250484
#   eval_f1_section = 0.8529147982062781
#   eval_f1_table = 0.6300148588410104
#   eval_f1_title = 0.6127659574468085
# Epoch 1, iteration 4200:
#   train_time = 33.77402383106528
#   train_loss = 0.8397832410782575
#   eval_time = 9.665096554075717
#   eval_time_scoring = 0.09640512100304477
#   eval_loss = 0.6521497165461041
#   eval_macro_p = 0.5548080445023469
#   eval_macro_r = 0.8193725144480575
#   eval_macro_f1 = 0.6057867036357459
#   eval_acc = 0.6470383047374043
#   eval_f1_abstract = 0.345679012345679
#   eval_f1_author = 0.7347560975609757
#   eval_f1_caption = 0.5315747402078338
#   eval_f1_date = 0.8148148148148148
#   eval_f1_equation = 0.8260715550832448
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.09922062350119905
#   eval_f1_list = 0.24153445417949324
#   eval_f1_paragraph = 0.6744810971089696
#   eval_f1_reference = 0.8785991738084962
#   eval_f1_section = 0.8607709750566894
#   eval_f1_table = 0.43185078909612623
#   eval_f1_title = 0.43786982248520706
# Epoch 1, iteration 4400:
#   train_time = 33.98591928402311
#   train_loss = 0.8275534777157009
#   eval_time = 9.687428993085632
#   eval_time_scoring = 0.09684060000290629
#   eval_loss = 0.7276007415849701
#   eval_macro_p = 0.5362758521521461
#   eval_macro_r = 0.8058648157664327
#   eval_macro_f1 = 0.5480200992706092
#   eval_acc = 0.5192177723516972
#   eval_f1_abstract = 0.31040892193308556
#   eval_f1_author = 0.6991643454038997
#   eval_f1_caption = 0.4378501135503407
#   eval_f1_date = 0.888888888888889
#   eval_f1_equation = 0.6144783754456673
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.12369477911646586
#   eval_f1_list = 0.14629997164729233
#   eval_f1_paragraph = 0.5169227547574798
#   eval_f1_reference = 0.8777894541633183
#   eval_f1_section = 0.876865671641791
#   eval_f1_table = 0.43283582089552236
#   eval_f1_title = 0.20105820105820107
# Epoch 1, iteration 4600:
#   train_time = 34.26832892396487
#   train_loss = 0.8753346380963921
#   eval_time = 9.711573093765764
#   eval_time_scoring = 0.09530396500485949
#   eval_loss = 0.7993716829548548
#   eval_macro_p = 0.5797289808432722
#   eval_macro_r = 0.7805595437799444
#   eval_macro_f1 = 0.6001700405114573
#   eval_acc = 0.5198282064139179
#   eval_f1_abstract = 0.4097951024487756
#   eval_f1_author = 0.29519450800915337
#   eval_f1_caption = 0.5921123716909779
#   eval_f1_date = 0.8799999999999999
#   eval_f1_equation = 0.8132299741602067
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.3403141361256544
#   eval_f1_list = 0.10850757029560203
#   eval_f1_paragraph = 0.46563685636856367
#   eval_f1_reference = 0.8730919641730793
#   eval_f1_section = 0.9050728277247615
#   eval_f1_table = 0.44478063540090773
#   eval_f1_title = 0.6764705882352942
# Epoch 1, iteration 4800:
#   train_time = 34.5694236021227
#   train_loss = 0.8109220018796622
#   eval_time = 9.72228356321284
#   eval_time_scoring = 0.0961326340038795
#   eval_loss = 0.8683259046689251
#   eval_macro_p = 0.6176857411547336
#   eval_macro_r = 0.7815572639530888
#   eval_macro_f1 = 0.6303456567782408
#   eval_acc = 0.6939109202293487
#   eval_f1_abstract = 0.21497265698661136
#   eval_f1_author = 0.697286012526096
#   eval_f1_caption = 0.5937161430119177
#   eval_f1_date = 0.9056603773584906
#   eval_f1_equation = 0.8455826966533949
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.48750000000000004
#   eval_f1_list = 0.22211645248294465
#   eval_f1_paragraph = 0.7427077132409219
#   eval_f1_reference = 0.8492123030757689
#   eval_f1_section = 0.9044652128764279
#   eval_f1_table = 0.46751188589540404
#   eval_f1_title = 0.2657580919931857
# Epoch 1, iteration 5000:
#   train_time = 34.58757349385996
#   train_loss = 0.9677302340604365
#   eval_time = 9.759916497132508
#   eval_time_scoring = 0.09468733600806445
#   eval_loss = 0.8510020593027227
#   eval_macro_p = 0.5576841535974003
#   eval_macro_r = 0.8038071942323385
#   eval_macro_f1 = 0.6017871886218612
#   eval_acc = 0.7936078833198893
#   eval_f1_abstract = 0.34443704197201863
#   eval_f1_author = 0.6269744835965979
#   eval_f1_caption = 0.6081117378458233
#   eval_f1_date = 0.2857142857142857
#   eval_f1_equation = 0.852744765138653
#   eval_f1_figure = 0.998003992015968
#   eval_f1_footer = 0.5052910052910053
#   eval_f1_list = 0.33058443886697747
#   eval_f1_paragraph = 0.8446940053216466
#   eval_f1_reference = 0.8674270296786852
#   eval_f1_section = 0.8617434758467519
#   eval_f1_table = 0.4832214765100672
#   eval_f1_title = 0.21428571428571425
# Epoch 1, iteration 5200:
#   train_time = 34.84644746498088
#   train_loss = 0.7091039663366974
#   eval_time = 9.72589916807192
#   eval_time_scoring = 0.09645620601077098
#   eval_loss = 0.7680950766597949
#   eval_macro_p = 0.5553023438863738
#   eval_macro_r = 0.8022339635675677
#   eval_macro_f1 = 0.5863355195297602
#   eval_acc = 0.5683577143604613
#   eval_f1_abstract = 0.2736954206602769
#   eval_f1_author = 0.7231467473524962
#   eval_f1_caption = 0.48976049982644915
#   eval_f1_date = 0.7999999999999999
#   eval_f1_equation = 0.8023201856148492
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.0865409454921209
#   eval_f1_list = 0.24672196949424677
#   eval_f1_paragraph = 0.5596481862782481
#   eval_f1_reference = 0.8758616406880706
#   eval_f1_section = 0.8557077625570776
#   eval_f1_table = 0.20780897063568893
#   eval_f1_title = 0.7011494252873562
# Epoch 1, iteration 5400:
#   train_time = 35.09719876688905
#   train_loss = 0.7841920022293926
#   eval_time = 9.725504303147318
#   eval_time_scoring = 0.09668416800559498
#   eval_loss = 0.6979579576867675
#   eval_macro_p = 0.5224249816068034
#   eval_macro_r = 0.8118366681084871
#   eval_macro_f1 = 0.5612056755647316
#   eval_acc = 0.5233600034881947
#   eval_f1_abstract = 0.3031194820482637
#   eval_f1_author = 0.7256637168141593
#   eval_f1_caption = 0.42467760844079727
#   eval_f1_date = 0.5517241379310345
#   eval_f1_equation = 0.8371294494677807
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.3896353166986564
#   eval_f1_list = 0.12545685089878422
#   eval_f1_paragraph = 0.4639130434782609
#   eval_f1_reference = 0.874914388892348
#   eval_f1_section = 0.8818818818818818
#   eval_f1_table = 0.3335180055401662
#   eval_f1_title = 0.38403990024937656
# Epoch 1, iteration 5600:
#   train_time = 34.12171287892852
#   train_loss = 1.0187257032189518
#   eval_time = 9.676163309879485
#   eval_time_scoring = 0.09583753799961414
#   eval_loss = 0.7937307188079424
#   eval_macro_p = 0.599463695667139
#   eval_macro_r = 0.8035851744676739
#   eval_macro_f1 = 0.637705355225169
#   eval_acc = 0.743029061021605
#   eval_f1_abstract = 0.26894865525672373
#   eval_f1_author = 0.6801075268817204
#   eval_f1_caption = 0.592059838895282
#   eval_f1_date = 0.7666666666666666
#   eval_f1_equation = 0.8475533249686323
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.5209003215434083
#   eval_f1_list = 0.246178600160901
#   eval_f1_paragraph = 0.7865220112664302
#   eval_f1_reference = 0.8773879385691096
#   eval_f1_section = 0.8549549549549549
#   eval_f1_table = 0.6491458607095926
#   eval_f1_title = 0.19974391805377723
# Epoch 1, iteration 5800:
#   train_time = 33.76161036112171
#   train_loss = 0.7861003087647259
#   eval_time = 11.555783301999327
#   eval_time_scoring = 0.09606407099636272
#   eval_loss = 0.6538244013815527
#   eval_macro_p = 0.570424092163406
#   eval_macro_r = 0.8248860104306069
#   eval_macro_f1 = 0.644553361105599
#   eval_acc = 0.7440973206304912
#   eval_f1_abstract = 0.30187590187590185
#   eval_f1_author = 0.7446808510638299
#   eval_f1_caption = 0.5045144647134697
#   eval_f1_date = 0.8363636363636364
#   eval_f1_equation = 0.8468111713213841
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.2614601018675722
#   eval_f1_list = 0.3035830618892508
#   eval_f1_paragraph = 0.78123348203903
#   eval_f1_reference = 0.8810051736881005
#   eval_f1_section = 0.8227311280746397
#   eval_f1_table = 0.562560620756547
#   eval_f1_title = 0.5323741007194245
# Epoch 1, iteration 6000:
#   train_time = 35.5221105080127
#   train_loss = 0.8507127258647234
#   eval_time = 9.667555042760796
#   eval_time_scoring = 0.09457840499817394
#   eval_loss = 0.9493443735648658
#   eval_macro_p = 0.6498295841867772
#   eval_macro_r = 0.7760210373290755
#   eval_macro_f1 = 0.6967256845184218
#   eval_acc = 0.7950031611763937
#   eval_f1_abstract = 0.40362355309511827
#   eval_f1_author = 0.7897271268057786
#   eval_f1_caption = 0.5561725758222982
#   eval_f1_date = 0.816326530612245
#   eval_f1_equation = 0.8411327575818438
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.4709302325581396
#   eval_f1_list = 0.3174603174603175
#   eval_f1_paragraph = 0.8357429158274672
#   eval_f1_reference = 0.8558900213320692
#   eval_f1_section = 0.7553846153846154
#   eval_f1_table = 0.686838124054463
#   eval_f1_title = 0.7282051282051283
# Save best model
# Epoch 1, iteration 6200:
#   train_time = 34.66101693002565
#   train_loss = 1.0054127850010992
#   eval_time = 9.695282491025864
#   eval_time_scoring = 0.09633387700887397
#   eval_loss = 0.676581751157003
#   eval_macro_p = 0.5828627531617894
#   eval_macro_r = 0.8219802679499654
#   eval_macro_f1 = 0.6477022980280067
#   eval_acc = 0.7140770454991389
#   eval_f1_abstract = 0.3095093882495457
#   eval_f1_author = 0.6432160804020101
#   eval_f1_caption = 0.39671069025666583
#   eval_f1_date = 0.7857142857142857
#   eval_f1_equation = 0.8514614799521895
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.3022508038585209
#   eval_f1_list = 0.30312500000000003
#   eval_f1_paragraph = 0.7460081368388818
#   eval_f1_reference = 0.8816991849839466
#   eval_f1_section = 0.8744271310724107
#   eval_f1_table = 0.682230869001297
#   eval_f1_title = 0.6437768240343347
# Epoch 1, iteration 6400:
#   train_time = 34.291340457988554
#   train_loss = 0.9507297051604837
#   eval_time = 9.680690010936814
#   eval_time_scoring = 0.09530981800344307
#   eval_loss = 0.7486839825546336
#   eval_macro_p = 0.6022333622018919
#   eval_macro_r = 0.7969240753814586
#   eval_macro_f1 = 0.6391149055640816
#   eval_acc = 0.6273518062307877
#   eval_f1_abstract = 0.40036563071297987
#   eval_f1_author = 0.7094017094017094
#   eval_f1_caption = 0.5792322834645669
#   eval_f1_date = 0.8571428571428571
#   eval_f1_equation = 0.7815224463240079
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.3682242990654206
#   eval_f1_list = 0.13736939151813152
#   eval_f1_paragraph = 0.6600084006160452
#   eval_f1_reference = 0.8780248126765754
#   eval_f1_section = 0.9007556675062972
#   eval_f1_table = 0.5581854043392506
#   eval_f1_title = 0.4782608695652174
# Epoch 1, iteration 6600:
#   train_time = 34.095106130989734
#   train_loss = 0.7858845093101263
#   eval_time = 9.661090606896323
#   eval_time_scoring = 0.09572082800150383
#   eval_loss = 0.8652122381085954
#   eval_macro_p = 0.6090295921702805
#   eval_macro_r = 0.7899721541701215
#   eval_macro_f1 = 0.6247135162218397
#   eval_acc = 0.6604024504567355
#   eval_f1_abstract = 0.30356100408639813
#   eval_f1_author = 0.4937560038424592
#   eval_f1_caption = 0.5888610763454318
#   eval_f1_date = 0.8571428571428571
#   eval_f1_equation = 0.8036939972544614
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.5119705340699816
#   eval_f1_list = 0.16834677419354835
#   eval_f1_paragraph = 0.7241371950568801
#   eval_f1_reference = 0.8253945583089338
#   eval_f1_section = 0.8191757779646762
#   eval_f1_table = 0.40076335877862596
#   eval_f1_title = 0.6244725738396624
# Epoch 1, iteration 6800:
#   train_time = 34.7397964791453
#   train_loss = 0.7612155404314399
#   eval_time = 9.96191465013544
#   eval_time_scoring = 0.09582324099028483
#   eval_loss = 0.7678022954583976
#   eval_macro_p = 0.5966334171811429
#   eval_macro_r = 0.8021836639661727
#   eval_macro_f1 = 0.6508554003285828
#   eval_acc = 0.7203557958534086
#   eval_f1_abstract = 0.42254901960784313
#   eval_f1_author = 0.4834749763928235
#   eval_f1_caption = 0.4450091769024424
#   eval_f1_date = 0.8148148148148148
#   eval_f1_equation = 0.8506388918715775
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.5055292259083728
#   eval_f1_list = 0.2133382461311717
#   eval_f1_paragraph = 0.7532680797735573
#   eval_f1_reference = 0.8811709253287026
#   eval_f1_section = 0.888782816229117
#   eval_f1_table = 0.6073059360730594
#   eval_f1_title = 0.5952380952380952
# Epoch 1, iteration 7000:
#   train_time = 34.112902231063345
#   train_loss = 0.8863932980597019
#   eval_time = 9.925172069924884
#   eval_time_scoring = 0.09398627300106455
#   eval_loss = 0.8181021812215833
#   eval_macro_p = 0.6332310435585095
#   eval_macro_r = 0.7827019282510626
#   eval_macro_f1 = 0.6790331592347673
#   eval_acc = 0.8183522640563343
#   eval_f1_abstract = 0.48304383788254757
#   eval_f1_author = 0.7751196172248804
#   eval_f1_caption = 0.4974533106960951
#   eval_f1_date = 0.45283018867924524
#   eval_f1_equation = 0.8578559027777778
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.4935064935064935
#   eval_f1_list = 0.34972677595628415
#   eval_f1_paragraph = 0.8631244253754213
#   eval_f1_reference = 0.879137603043754
#   eval_f1_section = 0.8430257979886313
#   eval_f1_table = 0.5679012345679012
#   eval_f1_title = 0.7647058823529412
# Epoch 1, iteration 7200:
#   train_time = 34.62026974609762
#   train_loss = 0.8572925937734545
#   eval_time = 9.920288592838915
#   eval_time_scoring = 0.09700887800136115
#   eval_loss = 0.7146861271444573
#   eval_macro_p = 0.5645743800884835
#   eval_macro_r = 0.823583136424407
#   eval_macro_f1 = 0.6338483446803421
#   eval_acc = 0.6878283808236499
#   eval_f1_abstract = 0.242319342276071
#   eval_f1_author = 0.672872340425532
#   eval_f1_caption = 0.46795685279187815
#   eval_f1_date = 0.7796610169491525
#   eval_f1_equation = 0.7690082271042401
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.2732782369146005
#   eval_f1_list = 0.3074857334676066
#   eval_f1_paragraph = 0.7077730997328987
#   eval_f1_reference = 0.8815724206349207
#   eval_f1_section = 0.8222789115646258
#   eval_f1_table = 0.6398963730569949
#   eval_f1_title = 0.675925925925926
# Epoch 1, iteration 7400:
#   train_time = 34.414431921060896
#   train_loss = 0.8898639568686485
#   eval_time = 9.942816096910974
#   eval_time_scoring = 0.095685185995535
#   eval_loss = 0.6917278392493352
#   eval_macro_p = 0.5803379048793036
#   eval_macro_r = 0.8199013923781655
#   eval_macro_f1 = 0.6352199060431144
#   eval_acc = 0.6960256382306133
#   eval_f1_abstract = 0.3644200626959248
#   eval_f1_author = 0.7816455696202531
#   eval_f1_caption = 0.36799999999999994
#   eval_f1_date = 0.7868852459016393
#   eval_f1_equation = 0.8335870710856073
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.5316846986089645
#   eval_f1_list = 0.25837122778007443
#   eval_f1_paragraph = 0.7303079344669341
#   eval_f1_reference = 0.8800636397013829
#   eval_f1_section = 0.8529280286097451
#   eval_f1_table = 0.4828685258964143
#   eval_f1_title = 0.3870967741935484
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-45f06a8f5581> in <module>
# ----> 1 experiment.train()
#
# ~/projects/sentclf/sentclf/experiment.py in train(self)
#     218
#     219     def train(self):
# --> 220         self.trainer.train(
#     221             self.train_data_loader,
#     222             self.dev_data_loader,
#
# ~/projects/sentclf/sentclf/trainer.py in train(self, train_data_loader, dev_data_loader, num_epochs, interval, verbose)
#      77                     batch = next(train_iter)
#      78
# ---> 79                 self._train_one_batch(batch)
#      80
#      81                 if self.iteration % interval == 0 or self.iteration == num_iterations:
#
# ~/projects/sentclf/sentclf/trainer.py in _train_one_batch(self, batch)
#     134
#     135         loss = self.criterion(outputs['logit'], targets)
# --> 136         loss.backward()
#     137         self.optimizer.step()
#     138
#
# ~/.conda/envs/nlp_gpu/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~/.conda/envs/nlp_gpu/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test Results

# %%
experiment.trainer.load_best_model()
experiment.test()
# Out:
#   eval_time = 9.899513032360119
#   eval_time_scoring = 0.0946564329933608
#   eval_loss = 0.9635102376135531
#   eval_macro_p = 0.6402710122251498
#   eval_macro_r = 0.773754726229301
#   eval_macro_f1 = 0.6899065707086789
#   eval_acc = 0.793106455340208
#   eval_f1_abstract = 0.4325699745547074
#   eval_f1_author = 0.7947019867549668
#   eval_f1_caption = 0.5456869009584664
#   eval_f1_date = 0.8571428571428572
#   eval_f1_equation = 0.8435374149659864
#   eval_f1_figure = 1.0
#   eval_f1_footer = 0.43310344827586206
#   eval_f1_list = 0.2986261749819234
#   eval_f1_paragraph = 0.8348669634124434
#   eval_f1_reference = 0.8543124925851229
#   eval_f1_section = 0.7516264829697665
#   eval_f1_table = 0.6303030303030303
#   eval_f1_title = 0.6923076923076924
